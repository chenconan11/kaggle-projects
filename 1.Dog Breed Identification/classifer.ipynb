# %%
from kaggleImageFolder import KaggleImageFolder

# %%
root = 'data'
train_dir = root + '/train'
test_dir = root + '/test'
labels_file = 'labels.csv'
train_data = KaggleImageFolder(train_dir, labels_file, mode='train', split_p=0.2)

# %%
train_data[0][0]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=450x338 at 0x257D2B24860>

# %%
print(len(train_data))
valid_data = KaggleImageFolder(train_dir, labels_file, mode='valid', split_p=0.2)
print(len(valid_data))
test_data = KaggleImageFolder(test_dir, mode='test')
print(len(test_data))
# Out:
# 8177
# 2045
# 10357

# %%
valid_data[0][0]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x150 at 0x257D2B71908>

# %%
test_data[0]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x449 at 0x257D2F8D9E8>

# %%
import torch
import torch.nn as nn
import torch.functional as F
import torchvision.datasets as dsets
import torchvision.transforms as transforms
from torchvision import models
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import os
import shutil 

# %matplotlib inline

# %%
# 读取数据，处理label
data_labels = pd.read_csv('labels.csv')
# data_labels.set_index('id', inplace=True)
# data_labels.head()

# %%
data_labels.head()
# Out:
#                                  id             breed
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever

# %%
breed_codes = data_labels['breed'].astype('category')
c = breed_codes.values

# %%
data_labels['label'] = c.codes
data_labels
# Out:
#                                      id                        breed  label
# 0      000bec180eb18c7604dcecc8fe0dba07                  boston_bull     19
# 1      001513dfcb2ffafc82cccf4d8bbaba97                        dingo     37
# 2      001cdf01b096e06d78e9e5112d419397                     pekinese     85
# 3      00214f311d5d2247d5dfe4fe24b2303d                     bluetick     15
# 4      0021f9ceb3235effd7fcde7f7538ed62             golden_retriever     49
# 5      002211c81b498ef88e1b40b9abf84e1d           bedlington_terrier     10
# 6      00290d3e1fdd27226ba27a8ce248ce85           bedlington_terrier     10
# 7      002a283a315af96eaea0e28e7163b21b                       borzoi     18
# 8      003df8b8a8b05244b1d920bb6cf451f9                      basenji      7
# 9      0042188c895a2f14ef64a918ed9c7b64           scottish_deerhound     97
# 10     004396df1acd0f1247b740ca2b14616e            shetland_sheepdog     99
# 11     0067dc3eab0b3c3ef0439477624d85d6                 walker_hound    113
# 12     00693b8bc2470375cc744a6391d397ec                  maltese_dog     73
# 13     006cc3ddb9dc1bd827479569fcdc52dc                     bluetick     15
# 14     0075dc49dab4024d12fafe67074d8a81              norfolk_terrier     79
# 15     00792e341f3c6eb33663e415d0715370          african_hunting_dog      2
# 16     007b5a16db9d9ff9d7ad39982703e429      wire-haired_fox_terrier    118
# 17     007b8a07882822475a4ce6581e70b1f8                      redbone     89
# 18     007ff9a78eba2aebb558afea3a51c469             lakeland_terrier     68
# 19     008887054b18ba3c7601792b6a453cc3                        boxer     21
# 20     008b1271ed1addaccf93783b39deab45                     doberman     38
# 21     008ba178d6dfc1a583617470d19c1673                   otterhound     83
# 22     009509be3ca7cce0ff9e37c8b09b1125                   otterhound     83
# 23     0097c6242c6f3071762d9f85c3ef1b2f           bedlington_terrier     10
# 24     00a338a92e4e7bf543340dc849230e75                        dingo     37
# 25     00a366d4b4a9bbb6c8a63126697b7656             golden_retriever     49
# 26     00a862390341c5be090dd72bd2bc19ef           standard_schnauzer    106
# 27     00b7d114bc5166a629a3cc03d9329120          irish_water_spaniel     58
# 28     00ba244566e36e0af3d979320fd3017f      black-and-tan_coonhound     12
# 29     00bee065dcec471f26394855c5c2f3de                        cairn     26
# ...                                 ...                          ...    ...
# 10192  ff4afeb51a1473f7ba18669a8ff48bc9               border_terrier     17
# 10193  ff4bb57ce419cd637dd511a1b5474bff                  appenzeller      5
# 10194  ff52a3909f5801a71161cec95d213107  west_highland_white_terrier    116
# 10195  ff54d45962b3123bb67052e8e29a60e7                      basenji      7
# 10196  ff63ed894f068da8e2bbdfda50a9a9f8                        boxer     21
# 10197  ff63fa05a58473138848f80840064d23                affenpinscher      0
# 10198  ff6f47aa8e181b6efa4d0be7b09b5628             golden_retriever     49
# 10199  ff7334b06cee8667a7f30eb00e0b93cf                      whippet    117
# 10200  ff7d9c08091acc3b18b869951feeb013                  maltese_dog     73
# 10201  ff84992beff3edd99b72718bec9448d2           bedlington_terrier     10
# 10202  ff8e3fa7e04faca99af85195507ee54d             sealyham_terrier     98
# 10203  ff91c3c095a50d3d7f1ab52b60e93638                affenpinscher      0
# 10204  ffa0055ec324829882186bae29491645                  maltese_dog     73
# 10205  ffa0ad682c6670db3defce2575a2587f             english_springer     41
# 10206  ffa16727a9ee462ee3f386be865b199e              irish_wolfhound     59
# 10207  ffa4e1bf959425bad9228b04af40ac76                      basenji      7
# 10208  ffa6a8d29ce57eb760d0f182abada4bf             english_foxhound     39
# 10209  ffbbf7536ba86dcef3f360bda41181b4                   weimaraner    114
# 10210  ffc1717fc5b5f7a6c76d0e4ea7c8f93a                   great_dane     51
# 10211  ffc2b6b9133a6413c4a013cff29f9ed2                 irish_setter     56
# 10212  ffc532991d3cd7880d27a449ed1c4770              tibetan_terrier    109
# 10213  ffca1c97cea5fada05b8646998a5b788             english_foxhound     39
# 10214  ffcb610e811817766085054616551f9c                       briard     23
# 10215  ffcde16e7da0872c357fbc7e2168c05f                     airedale      3
# 10216  ffcffab7e4beef9a9b8076ef2ca51909                      samoyed     94
# 10217  ffd25009d635cfd16e793503ac5edef0                       borzoi     18
# 10218  ffd3f636f7f379c51ba3648a9ff8254f               dandie_dinmont     35
# 10219  ffe2ca6c940cddfee68fa3cc6c63213f                     airedale      3
# 10220  ffe5f6d8e2bff356e9482a80a6e29aac           miniature_pinscher     75
# 10221  fff43b07992508bc822f33d8ffd902ae     chesapeake_bay_retriever     28
#
# [10222 rows x 3 columns]

# %%
data_labels['label'].values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-37132b2f7f29> in <module>
# ----> 1 data_labels['label'].values.unique()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'unique'

# %%
data_labels.groupby('breed').size().describe()
# Out:
# count    120.000000
# mean      85.183333
# std       13.298122
# min       66.000000
# 25%       75.000000
# 50%       82.000000
# 75%       91.250000
# max      126.000000
# dtype: float64

# %%
pd.Series.name

# %%
data_labels.loc['000bec180eb18c7604dcecc8fe0dba07'].values[0]
# Out:
# 'boston_bull'

# %%
g = os.walk(r"data/train")  

for i, (path,dir_list,file_list) in enumerate(g):  
    if i == 0:
        print(file_list)

#     for file_name in file_list:  
#         print(os.path.join(path, file_name) )
# Out:
d1ab82fbff3ace9938.jpg', '01680178ca6664294efb493a46014a82.jpg', '0169294085e94d1250587b38e4fbb532.jpg', '016bcdb05e2d0e0878877df21b8c3cff.jpg', '0177a92a906192bfde8adbb8a237e524.jpg', '018aae5768833c34e3df30d63429251e.jpg', '0192d7174233ebdb3d720000413829ac.jpg', '019c92d1ff56deb9d75d809a92bc84d8.jpg', '019ff93e03802e661577b5869e099dcb.jpg', '01a3b064c56edbe3abf55051b16134d4.jpg', '01a41985ab8209e750588fa348d635be.jpg', '01b09bdac592b0eb9909dd105314ad3a.jpg', '01b35a06b00e4a832b935cf8d51303c1.jpg', '01b36cb1b80ab8c3a7d2b7128ad21bdc.jpg', '01b6c2bd3053535a58d8de763cf06aa0.jpg', '01b849a7e4fbc545f6b2806cb87ab371.jpg', '01c230ec18eed427cf5b1db1a833024d.jpg', '01d0f3692e576b3cde511285352aed4a.jpg', '01de1f7b7b4465a6d130a56746af66a6.jpg', '01dffcb02d6cba7d2b101fcc93daa6f1.jpg', '01e2245b46eb747260ff80f1c892daef.jpg', '01e4d3d1cb704ed819bce35d22e716a7.jpg', '01e787576c003930f96c966f9c3e1d44.jpg', '01ee3c7ff9bcaba9874183135877670e.jpg', '01f397f16fb2d7d76fdbce4e2207c1a3.jpg', '01f429667104c0c5a5f321700f15435c.jpg', '01f8540fb1084107a6eb3e528f82c1aa.jpg', '0206c12e8984e3c8a166cc272de25d6f.jpg', '0207803a6ce1bfad98e7f095c965e44a.jpg', '020ecfccf3c900b01ce831abbf20b485.jpg', '0214e2d616ec7eb7cb0d8c19a7f29e70.jpg', '021b5a49189665c0442c19b5b33e8cf1.jpg', '0229677aec75183a16de9d6f6658fae2.jpg', '022b34fd8734b39995a9f38a4f3e7b6b.jpg', '0234695e7a548e2ad1b2ac91d6486c1c.jpg', '023e4e28415506e0deddcbd8f8bdab29.jpg', '0246f44bb123ce3f91c939861eb97fb7.jpg', '024ecfa590271db8616bfaa59159d7b2.jpg', '024fc0be976885d5cfcf6770239a9001.jpg', '024fd994941146f8dfdb38a9b2b74efd.jpg', '02508e76981e1ba059d785704b4c480c.jpg', '0255a5bca3b9d91d4fdba8d7419b5e69.jpg', '025bab46ddcde249d5c52c660fea6d26.jpg', ...

# %%
root_dir = 'data'

def WinContig(root_dir, data_labels, data_for='train'):
    data_dir = os.path.join(root_dir, data_for)
   
    if os.path.exists(data_dir):
        # 遍历data_dir
        for path, _, file_list in os.walk(data_dir):
            for file_name in file_list:  
                img_path = os.path.join(path, file_name)
                img_label = data_labels.loc[file_name.split('.')[0]].values[0]
                class_path = os.path.join(path, img_label)
                if not os.path.exists(class_path):
                    os.mkdir(class_path)
                
                shutil.move(img_path, class_path)

# %%
# 整理图像文件结构为ImageFolder支持类型
WinContig(root_dir, data_labels)

# %%
# 读取数据
data_dir = 'data'
train_dir = data_dir + '/train'
test_dir = data_dir + '/test'

# %%
train_data_transforms = transforms.Compose([
    transforms.RandomCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.Ran
])
